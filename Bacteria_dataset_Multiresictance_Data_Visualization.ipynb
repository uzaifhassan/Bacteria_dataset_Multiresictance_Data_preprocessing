# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Update_Bacteria_dataset.csv")
df.head(20)
# Out:
#       ID                Name                           Email  Age Gender  \
# 0   S290  Elizabeth Lawrence  elizabeth.lawrence@example.com   37      F
# 1   S291        Tina Sanders        tina.sanders@example.com   29      F
# 2   S292          Erin Cooke          erin.cooke@example.com   77      F
# 3   S293  Mrs. Sharon Watson  mrs..sharon.watson@example.com   45      F
# 4   S294       Erika Stewart       erika.stewart@example.com   13      F
# 5   S295       Krystal Riley       krystal.riley@example.com   57      M
# 6   S296        Gina Griffin        gina.griffin@example.com   68      F
# 7   S297        Faith Newman        faith.newman@example.com   18      F
# 8   S298       Russell Hicks       russell.hicks@example.com   77      F
# 9   S299  Kimberly Rodriguez  kimberly.rodriguez@example.com   36      F
# 10  S300         Brian Woods         brian.woods@example.com   49      M
# 11  S301      Keith Mcdonald      keith.mcdonald@example.com   47      F
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Email', 'Age', 'Gender', 'Address', 'Souches',
#        'Diabetes', 'Hypertension', 'Hospital_before', 'Infection_Freq',
#        'AMX/AMP', 'AMC', 'CZ', 'FOX', 'CTX/CRO', 'IPM', 'GEN', 'AN',
#        'Acide nalidixique', 'ofx', 'CIP', 'C', 'Co-trimoxazole', 'Furanes',
#        'colistine', 'Collection_Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 10710 non-null  object
#  1   Name               10710 non-null  object
#  2   Email              10710 non-null  object
#  3   Age                10710 non-null  int64
#  4   Gender             10710 non-null  object
#  5   Address            10710 non-null  object
#  6   Souches            10710 non-null  object
#  7   Diabetes           10710 non-null  object
#  8   Hypertension       10710 non-null  object
#  9   Hospital_before    10710 non-null  object
#  10  Infection_Freq     10710 non-null  float64
#  11  AMX/AMP            10710 non-null  object
#  12  AMC                10710 non-null  object
#  13  CZ                 10710 non-null  object
#  14  FOX                10710 non-null  object
#  15  CTX/CRO            10710 non-null  object
# ...

# %% [markdown]
# ## Which bacterial strain (Souches) appears most frequently in the dataset?

# %%
df["Souches"].value_counts()
# Out:
# Souches
# S10287 Morganella morganii    157
# S292 Proteus mirabilis        136
# S291 Morganella morganii      125
# S290 Escherichia coli         122
# S10288 Escherichia coli       116
#                              ...
# S3742 Enterobacteria spp.       1
# S3741 Enterobacteria spp.       1
# S3740 Escherichia coli          1
# S3739 Escherichia coli          1
# S10286 Citrobacter spp.         1
# Name: count, Length: 9296, dtype: int64

# %%
top = df["Souches"].value_counts().head(300)

plt.figure(figsize=(20,100))

sns.barplot(
    y=top.index,
    x=top.values
)

plt.xlabel("Count")
plt.ylabel("Souches")
plt.show()

# %% [markdown]
# ## What is the distribution of patients by gender?

# %%
plt.figure(figsize=(10,8))
tot=df["Gender"].value_counts()
tot.plot(kind="bar")

plt.xlabel("Gender")
plt.ylabel("Numbers Patients")
plt.show()

# %% [markdown]
# ## How are patients distributed across different age groups?

# %%
plt.figure(figsize=(10,8))
bins = [0, 20, 40, 60, 80, 100]
labels = ["0-20", "21-40", "41-60", "61-80", "81-100"]
df["Age_Group"] = pd.cut(df["Age"], bins=bins, labels=labels)
patient_grp=df["Age_Group"].value_counts()
plt.pie(patient_grp,autopct="%1.1f%%",labels=labels)

plt.xticks(rotation=45)
plt.show()
